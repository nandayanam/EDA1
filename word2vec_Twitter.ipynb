# %% [markdown]
# <a href="https://colab.research.google.com/github/nandayanam/EDA1/blob/master/word2vec_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
data=  pd.read_csv("/content/drive/MyDrive/Gen AI files/twcs.csv")

# %%
data.head()
# Out:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# ...

# %%
twitter_text=data["text"]

# %%
twitter_text
# Out:
# 0          @115712 I understand. I would like to assist y...
# 1              @sprintcare and how do you propose we do that
# 2          @sprintcare I have sent several private messag...
# 3          @115712 Please send us a Private Message so th...
# 4                                         @sprintcare I did.
#                                  ...
# 1359100    @122255 Nice! I'll be here again at the weeken...
# 1359101       @VirginTrains mild here any plans this weekend
# 1359102    @122255 It's not too bad thanks, we'll just be...
# 1359103    @VirginTrains am ok hows the weather were u ar...
# 1359104    @122255 Hi 👋  all good here thank you! Yoursel...
# Name: text, Length: 1359105, dtype: object

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
processed_sentences=[]
for sentence in twitter_text:
  processed_sentences.append(" ".join(simple_preprocess(sentence)))

# %%
processed_sentences
# Out:
# ['understand would like to assist you we would need to get you into private secured link to further assist',
#  'sprintcare and how do you propose we do that',
#  'sprintcare have sent several private messages and no one is responding as usual',
#  'please send us private message so that we can further assist you just click message at the top of your profile',
#  'sprintcare did',
#  'can you please send us private message so that can gain further details about your account',
#  'sprintcare is the worst customer service',
#  'this is saddening to hear please shoot us dm so that we can look into this for you kc',
#  'sprintcare you gonna magically change your connectivity for me and my whole family',
#  'we understand your concerns and we like for you to please send us direct message so that we can further assist you aa',
#  'sprintcare since signed up with you since day',
#  'there we definitely like to work with you on this how long have you been experiencing this issue aa',
# ...

# %% [markdown]
# TOKENIZE

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Tokenization using simple_preprocess
tokens=[word_tokenize(sentence) for sentence in processed_sentences]

# %%
tokens
# Out:
# [['understand',
#   'would',
#   'like',
#   'to',
#   'assist',
#   'you',
#   'we',
#   'would',
#   'need',
#   'to',
#   'get',
#   'you',
#   'into',
#   'private',
#   'secured',
#   'link',
#   'to',
#   'further',
#   'assist'],
#  ['sprintcare', 'and', 'how', 'do', 'you', 'propose', 'we', 'do', 'that'],
#  ['sprintcare',
#   'have',
#   'sent',
#   'several',
#   'private',
#   'messages',
#   'and',
#   'no',
#   'one',
#   'is',
#   'responding',
#   'as',
#   'usual'],
#  ['please',
#   'send',
#   'us',
#   'private',
#   'message',
#   'so',
#   'that',
#   'we',
#   'can',
#   'further',
#   'assist',
#   'you',
#   'just',
#   'click',
#   'message',
#   'at',
#   'the',
#   'top',
#   'of',
#   'your',
#   'profile'],
#  ['sprintcare', 'did'],
#  ['can',
#   'you',
#   'please',
#   'send',
#   'us',
#   'private',
#   'message',
#   'so',
#   'that',
#   'can',
#   'gain',
#   'further',
#   'details',
#   'about',
#   'your',
#   'account'],
# ...

# %%
twitter_tokens = [
    [word for word in sentence if all(ord(char) < 128 for char in word)]
    for sentence in tokens
]

# %%
print(ascii_words[:100])
# Out:
# [['understand', 'would', 'like', 'to', 'assist', 'you', 'we', 'would', 'need', 'to', 'get', 'you', 'into', 'private', 'secured', 'link', 'to', 'further', 'assist'], ['sprintcare', 'and', 'how', 'do', 'you', 'propose', 'we', 'do', 'that'], ['sprintcare', 'have', 'sent', 'several', 'private', 'messages', 'and', 'no', 'one', 'is', 'responding', 'as', 'usual'], ['please', 'send', 'us', 'private', 'message', 'so', 'that', 'we', 'can', 'further', 'assist', 'you', 'just', 'click', 'message', 'at', 'the', 'top', 'of', 'your', 'profile'], ['sprintcare', 'did'], ['can', 'you', 'please', 'send', 'us', 'private', 'message', 'so', 'that', 'can', 'gain', 'further', 'details', 'about', 'your', 'account'], ['sprintcare', 'is', 'the', 'worst', 'customer', 'service'], ['this', 'is', 'saddening', 'to', 'hear', 'please', 'shoot', 'us', 'dm', 'so', 'that', 'we', 'can', 'look', 'into', 'this', 'for', 'you', 'kc'], ['sprintcare', 'you', 'gon', 'na', 'magically', 'change', 'your', 'connectivity', 'for', 'me
# ...

# %%
pip install gensim

# %%
from gensim.models import Word2Vec

# %%
model=Word2Vec(sentences=twitter_tokens,vector_size=100,window=5,min_count=2)

# %%
vector_for_word=model.wv['thanks']

# %%
print(vector_for_word)
# Out:
# [ 4.2317063e-01 -9.0580076e-01 -1.6963207e+00 -2.0206480e+00
#   1.6351051e+00 -4.7575641e+00  2.2877715e+00  2.6854248e+00
#   8.1043214e-02 -8.0800796e-01 -3.6134930e+00  1.1698109e+00
#  -2.5547810e+00  9.2871648e-01  1.1528374e+00 -1.6057143e-01
#   8.3244964e-02  5.5189550e-01 -6.5968949e-01  3.7913780e+00
#   2.6197633e-01 -6.3471627e-01 -1.0238084e-01  3.5559752e+00
#   1.4798468e+00 -1.7884402e+00 -1.1907021e+00 -1.5806781e+00
#   4.1600780e+00 -4.7224422e+00 -1.4967854e+00 -1.7719669e+00
#  -1.1416130e+00 -1.3168657e+00 -4.6669543e-01 -8.3084923e-01
#   2.7765877e+00  4.2228441e+00 -2.1880960e+00 -8.6502081e-01
#  -8.1820816e-01 -1.6327509e+00  9.7508453e-02 -2.2465336e+00
#   2.3271413e+00  2.4154654e+00 -1.3167171e+00 -1.4588937e+00
#  -4.4761143e+00  1.6814604e+00 -2.0985729e-01 -3.4222472e-01
#  -5.1239121e-01  2.9916033e-01  1.9657482e-01  1.4082173e+00
#   1.3293011e+00 -2.5943224e+00  2.0349120e-01  1.7857357e+00
# ...

# %%
# Get the vector for an entire sentence
vector_for_sentence = model.wv[twitter_tokens[0]].mean(axis=0)
print(f"Vector for the first sentence: {vector_for_sentence}")
# Out:
# Vector for the first sentence: [-0.16101979  0.7028436   1.5796424   0.3421801   0.38875875 -0.8339902
#   2.0471642  -0.33444354  0.8694203  -0.05636656 -0.3302845   0.27003786
#   0.65083796 -0.4498065   0.08283426  0.4170196   0.5404804   0.32346836
#  -0.46813995 -0.04425596 -0.18980038  1.1435877  -1.8212601   1.4528381
#   1.4668125   0.64385635 -0.61797863  0.75507677  0.04109352  0.07539473
#  -0.07118035  0.36748657  0.8146497  -0.8136793  -1.3149397   1.2924767
#  -0.7332871   0.9471186  -1.37318    -0.97662085  0.03443822 -2.74282
#  -1.325072   -0.6024662   1.2001816   0.3054618   0.31866565 -0.85368377
#   0.43981662 -0.25584394 -0.15302734 -1.2550106  -0.2576958   0.7876442
#  -0.8382162   1.3403414   0.8175598  -1.9332279  -1.1345696   1.1289518
#   0.9159853  -0.4962494   1.6745199   0.8204808   1.9114529  -0.27959964
#   0.38967702  2.0335145  -0.4028423   1.1725538   0.6533542   1.4273354
#   0.3220563   1.3116682  -1.335322    0.00421404 -0.9518536   1.0471646
# ...
